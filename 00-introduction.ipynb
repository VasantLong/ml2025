# %% [markdown]
# <center><img src="attachment:45a97f18-f320-4acf-afc7-cdc74245f30d.png"></center>

# %% [markdown]
# ## 机器学习(Machine Learning)
#
# 机器学习是人工智能 (AI) 和计算机科学的分支，专注于使用数据和算法来模仿人类学习的方式，逐渐提高其准确性。

# %% [markdown]
# <center><img src="attachment:81e6941a-f220-4bf0-862f-bf580b6f6e53.png"></center>
# <br>
# <center><img src="attachment:636f3429-ba8f-4673-9bac-472d85eca131.png"></center>

# %% [markdown]
# ## 机器学习三要素：模型、策略与算法
#
# * **模型(Model)** \
# 模型表示机器学习算法所学到的内容。\
# 通俗点说就是，你知道对于这个问题，它的模型大概长什么样子的，然后通过训练数据(traning data)，学习出一个参数合理的模型。
#
# * **策略(Strategy)** \
# 就是使用一种什么样的评价度量模型训练过程中的学习好坏的方法。\
# 学习的模型，不会只有一个，究竟哪个好？不同的策略，对应不同的模型的比较标准和选择标准。
#
# * **算法(Algorithm)** \
# 算法就是在知道模型何为最优的情况下，去假设空间中找到最优的过程。 \
# 有了数据，有了学习模型的策略，然后就要开始去构造模型了，如果模型的基本形式有了，就是一个优化模型参数的问题了。

# %% [markdown]
# ## 机器学习方法
#
# * **监督式机器学习( supervised learning)** \
# 监督式学习（也称为监督式机器学习）使用标签化数据集训练算法，以准确分类数据或预测结果。
#
#   * 分类(classification)
#   * 回归(regression)
#   * ...
#
#   <br>
#
# * **无监督机器学习(unsupervised learning)** \
# 无监督学习也称为无监督机器学习，使用机器学习算法来分析未标签化数据集并形成聚类。
#
#     * 降维(dimensionality reduction)
#     * 聚类(clustering)
#     * 关联规则(association rules)
#     * ...
#
# <br>
#
# * **强化学习(reinforcement learning)** \
# 强化机器学习是一种行为机器学习模型，类似于监督式学习，但算法未使用样本数据进行训练。 此模型通过不断试错进行学习。 将强化一系列成功结果，为某一问题提出最佳建议或制定最佳策略。
# ![image.png](attachment:b1d30877-bc67-45e5-bc1d-d3329b93f462.png)
#
#
# <br><br>
# <center><img src="attachment:e333cbb3-8d36-4bb3-95b0-2343bd42efa3.png"></center>

# %% [markdown]
# ![image.png](attachment:cbbb4b48-d84d-4495-9a84-2afe8bf03207.png)

# %% [markdown]
# <center><img src="attachment:bb45036c-d879-4b42-8662-309b7a741bdf.png" style="width: 80%"></center>

# %% [markdown]
# ## 岗位与职责
#
# ![image.png](attachment:585208b4-0a1b-4993-b188-5b76b6727d3d.png)

# %% [markdown]
# <center><img src="attachment:4460e905-966a-4415-886a-4ed49e35a627.png" style="width:80%"></center>
